# %% [markdown]
# ### Import Libraries

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import warnings 
warnings.simplefilter('ignore')

# %% [markdown]
# ### Importing Datasets

# %%
df = pd.read_csv('C:/Users/ZASHANK/Downloads/Breast_Cancer/data.csv')
df.head(5)
# Out:
#          id diagnosis  Radius_mean  Texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         21.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %% [markdown]
# ### Shape of dataset:

# %%
df.shape
# Out:
# (569, 32)

# %%
# Getting infos 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 32 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       569 non-null    int64
#  1   diagnosis                569 non-null    object
#  2   Radius_mean              569 non-null    float64
#  3   Texture_mean             569 non-null    float64
#  4   perimeter_mean           569 non-null    float64
#  5   area_mean                569 non-null    float64
#  6   smoothness_mean          569 non-null    float64
#  7   compactness_mean         569 non-null    float64
#  8   concavity_mean           569 non-null    float64
#  9   concave points_mean      569 non-null    float64
#  10  symmetry_mean            569 non-null    float64
#  11  fractal_dimension_mean   569 non-null    float64
#  12  radius_se                569 non-null    float64
#  13  texture_se               569 non-null    float64
# ...

# %%
df.describe()
# Out:
#                  id  Radius_mean  Texture_mean  perimeter_mean    area_mean  \
# count  5.690000e+02   569.000000    569.000000      569.000000   569.000000
# mean   3.037183e+07    14.127292     19.296678       91.969033   654.889104
# std    1.250206e+08     3.524049      4.301816       24.298981   351.914129
# min    8.670000e+03     6.981000      9.710000       43.790000   143.500000
# 25%    8.692180e+05    11.700000     16.170000       75.170000   420.300000
# 50%    9.060240e+05    13.370000     18.870000       86.240000   551.100000
# 75%    8.813129e+06    15.780000     21.800000      104.100000   782.700000
# max    9.113205e+08    28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# ...

# %% [markdown]
# ### Checking the null values

# %%
# Checking Null values
df.isnull().sum()

# There is no null values
# Out:
# id                         0
# diagnosis                  0
# Radius_mean                0
# Texture_mean               0
# perimeter_mean             0
# area_mean                  0
# smoothness_mean            0
# compactness_mean           0
# concavity_mean             0
# concave points_mean        0
# symmetry_mean              0
# fractal_dimension_mean     0
# radius_se                  0
# texture_se                 0
# perimeter_se               0
# area_se                    0
# smoothness_se              0
# compactness_se             0
# concavity_se               0
# concave points_se          0
# symmetry_se                0
# fractal_dimension_se       0
# radius_worst               0
# texture_worst              0
# perimeter_worst            0
# area_worst                 0
# smoothness_worst           0
# compactness_worst          0
# concavity_worst            0
# concave points_worst       0
# symmetry_worst             0
# fractal_dimension_worst    0
# ...

# %% [markdown]
# #### Taking the values of id column into another variable before dropping it

# %%
df_id = df['id']

# %%
df_id
# Out:
# 0        842302
# 1        842517
# 2      84300903
# 3      84348301
# 4      84358402
#          ...
# 564      926424
# 565      926682
# 566      926954
# 567      927241
# 568       92751
# Name: id, Length: 569, dtype: int64

# %% [markdown]
# ### Dropping id column

# %%
# Dropping id col
df = df.drop(['id'],axis = 1)

# %% [markdown]
# ### Plotting

# %%
df.columns
# Out:
# Index(['diagnosis', 'Radius_mean', 'Texture_mean', 'perimeter_mean',
#        'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
#        'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
#        'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
#        'fractal_dimension_se', 'radius_worst', 'texture_worst',
#        'perimeter_worst', 'area_worst', 'smoothness_worst',
#        'compactness_worst', 'concavity_worst', 'concave points_worst',
#        'symmetry_worst', 'fractal_dimension_worst'],
#       dtype='object')

# %%
col = ['Radius_mean', 'Texture_mean', 'perimeter_mean',
       'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
       'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
       'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
       'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
       'fractal_dimension_se', 'radius_worst', 'texture_worst',
       'perimeter_worst', 'area_worst', 'smoothness_worst',
       'compactness_worst', 'concavity_worst', 'concave points_worst',
       'symmetry_worst', 'fractal_dimension_worst']

# %%
df_corr = df.corr()

# %%
ax ,plot1 = plt.subplots(figsize = (16,8))

sns.heatmap(df_corr)
plt.show()

# %% [markdown]
# #### Plotting Boxplot for all the independent variables for checking outliers

# %%
for i in col:
    ax ,plot1 = plt.subplots(figsize = (4,4))

    plot1.boxplot(df[i])
    plt.xlabel(i)
    plt.show()

# %%
# As can be seen there are outliers in many variables, so now will treat then using IQR method

# %%
for i in col:
    Q1 = np.percentile(df[i], 25,interpolation = 'midpoint') # Quartile 1 value
    Q3 = np.percentile(df[i], 75,interpolation = 'midpoint') # Quartile 3 value
    IQR = Q3 - Q1 # Getting the interquartile range value
    #upper fence
    uf = Q3+1.5*IQR
    
    # lower fence
    lf = Q1-1.5*IQR
    
    #Taking the indices of the values which are not present in between upper and lower fence
    upper = np.where(df[i] >= uf) # for upper fence
    lower = np.where(df[i] <= lf) # for lower fence
 
    #Removing the Outliers
    df.drop(upper[0], inplace = True)
    df.drop(lower[0], inplace = True)
    df.reset_index(inplace = True,drop=True)

# %% [markdown]
# #### Checking the shape of new data after removing outliers

# %%
df.shape
# Out:
# (276, 31)

# %% [markdown]
# #### Again plotting after removing outliers

# %%
for i in col:
    ax ,plot1 = plt.subplots(figsize = (4,4))

    plot1.boxplot(df[i])
    plt.xlabel(i)
    plt.show()

# %%
# Most of the outliers are removed but we nearly lost half of the data
# Still there are some of the variables which have outliers

# %%
# Plotting for 'Texture_mean'
ax ,plot1 = plt.subplots(figsize = (4,4))

plot1.boxplot(df['Texture_mean'])
plt.xlabel('Texture_mean')
plt.show()

# %%
# Removing outliers
df = df.loc[df['Texture_mean'] < 24.5]

# %%
#Without Outliers
ax ,plot1 = plt.subplots(figsize = (4,4))

plot1.boxplot(df['Texture_mean'])
plt.xlabel('Texture_mean')
plt.show()

# %%
# Plotting for 'concavity_se'
ax ,plot1 = plt.subplots(figsize = (4,4))

plot1.boxplot(df['concavity_se'])
plt.xlabel('concavity_se')
plt.show()

# %%
# Removing outliers
df = df.loc[df['concavity_se'] < 0.04]

# %%
# Without outliers
ax ,plot1 = plt.subplots(figsize = (4,4))

plot1.boxplot(df['concavity_se'])
plt.xlabel('concavity_se')
plt.show()

# %%
# Checking outliers
ax ,plot1 = plt.subplots(figsize = (4,4))

plot1.boxplot(df['concave points_mean'])
plt.xlabel('concave points_mean')
plt.show()

# %%
# Removing outliers
df = df.loc[df['concave points_mean'] < 0.055]

# %%
# Without outliers
ax ,plot1 = plt.subplots(figsize = (4,4))

plot1.boxplot(df['concave points_mean'])
plt.xlabel('concave points_mean')
plt.show()

# %%
# Plotting for 'area_se'
ax ,plot1 = plt.subplots(figsize = (4,4))

plot1.boxplot(df['area_se'])
plt.xlabel('area_se')
plt.show()

# %%
# Removing outliers
df = df.loc[df['area_se'] < 35]

# %%
# # Without outliers
ax ,plot1 = plt.subplots(figsize = (4,4))

plot1.boxplot(df['area_se'])
plt.xlabel('area_se')
plt.show()

# %%
# Plotting for 'concavity_mean'
ax ,plot1 = plt.subplots(figsize = (4,4))

plot1.boxplot(df['concavity_mean'])
plt.xlabel('concavity_mean')
plt.show()

# %%
# Removing outliers
df = df.loc[df['concavity_mean'] < 0.08]

# %%
# # Without outliers
ax ,plot1 = plt.subplots(figsize = (4,4))

plot1.boxplot(df['concavity_mean'])
plt.xlabel('concavity_mean')
plt.show()

# %%
# Checcking for 'fractal_dimension_se'
ax ,plot1 = plt.subplots(figsize = (4,4))

plot1.boxplot(df['fractal_dimension_se'])
plt.xlabel('fractal_dimension_se')
plt.show()

# %%
# Removing outliers
df = df.loc[df['fractal_dimension_se'] < 0.0043]

# %%
# Without outliers
ax ,plot1 = plt.subplots(figsize = (4,4))

plot1.boxplot(df['fractal_dimension_se'])
plt.xlabel('fractal_dimension_se')
plt.show()

# %%
# Checking for 'compactness_se'
ax ,plot1 = plt.subplots(figsize = (4,4))

plot1.boxplot(df['compactness_se'])
plt.xlabel('compactness_se')
plt.show()

# %%
# Removing outliers
df = df.loc[df['compactness_se'] < 0.03]

# %%
# Without outliers
ax ,plot1 = plt.subplots(figsize = (4,4))

plot1.boxplot(df['compactness_se'])
plt.xlabel('compactness_se')
plt.show()

# %%
df.shape
# Out:
# (197, 31)

# %%
df.head()
# Out:
#   diagnosis  Radius_mean  Texture_mean  perimeter_mean  area_mean  \
# 1         B       13.540         14.36           87.46      566.3
# 2         B       13.080         15.71           85.63      520.0
# 3         B        9.504         12.44           60.34      273.9
# 4         B       13.030         18.42           82.61      523.8
# 5         M       13.440         21.58           86.18      563.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 1          0.09779           0.08129         0.06664              0.04781
# 2          0.10750           0.12700         0.04568              0.03110
# 3          0.10240           0.06492         0.02956              0.02076
# 4          0.08983           0.03766         0.02562              0.02923
# 5          0.08162           0.06031         0.03110              0.02031
#
#    symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# ...

# %% [markdown]
# ### Encoding of categorical variable i.e. Diagnosis

# %%
# Checking for the Unique Elements of Diagnosis column
df.diagnosis.unique
# Out:
# <bound method Series.unique of 1      B
# 2      B
# 3      B
# 4      B
# 5      M
#       ..
# 265    B
# 266    B
# 267    B
# 268    B
# 269    B
# Name: diagnosis, Length: 197, dtype: object>

# %%
# As it has only 2 unique values i.e. M and B, we can do label encoding manually by making dictionary and map()

# %%
tempdict = {'M':1,'B':0}
df['diagnosis'] = df['diagnosis'].map(tempdict)
df['diagnosis']
# Out:
# 1      0
# 2      0
# 3      0
# 4      0
# 5      1
#       ..
# 265    0
# 266    0
# 267    0
# 268    0
# 269    0
# Name: diagnosis, Length: 197, dtype: int64

# %% [markdown]
# #### Taking the Target values into y variables

# %%
X = df.drop(['diagnosis'],axis = 1)
y = df['diagnosis']

# %% [markdown]
# ### Modeling

# %%
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score

# %% [markdown]
# #### Splitting data into Train and Test

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.3,random_state = 0)

# %%
from sklearn.preprocessing import StandardScaler
ss = StandardScaler()
X_train = ss.fit_transform(X_train)
X_test = ss.transform(X_test)

# %% [markdown]
# #### Model and Fit

# %%
GNB = GaussianNB()
GNB.fit(X_train,y_train)
y_pred = GNB.predict(X_test)

# %% [markdown]
# ##### Score

# %%
print(accuracy_score(y_test,y_pred))
# Out:
# 0.95
